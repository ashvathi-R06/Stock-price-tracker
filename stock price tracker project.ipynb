# %%
import yfinance as yf
import pandas as pd

# %%
stock = yf.Ticker("INFY.NS")

# %%
data = stock.history(period="1d")

# %%
print(data[['Close']])
# Out:
#                                  Close
# Date
# 2026-04-02 00:00:00+05:30  1268.199951

# %%
print(data[['Open','Close','High','Low']])
# Out:
#                              Open        Close         High          Low
# Date
# 2026-04-02 00:00:00+05:30  1260.0  1268.199951  1276.699951  1259.800049
